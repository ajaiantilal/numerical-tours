# %% [markdown]
# Non Local Means
# ===============
#
# *Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.
# $\newcommand{\dotp}[2]{\langle #1, #2 \rangle}$
# $\newcommand{\enscond}[2]{\lbrace #1, #2 \rbrace}$
# $\newcommand{\pd}[2]{ \frac{ \partial #1}{\partial #2} }$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\umax}[1]{\underset{#1}{\max}\;}$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\uargmin}[1]{\underset{#1}{argmin}\;}$
# $\newcommand{\norm}[1]{\|#1\|}$
# $\newcommand{\abs}[1]{\left|#1\right|}$
# $\newcommand{\choice}[1]{ \left\{  \begin{array}{l} #1 \end{array} \right. }$
# $\newcommand{\pa}[1]{\left(#1\right)}$
# $\newcommand{\diag}[1]{{diag}\left( #1 \right)}$
# $\newcommand{\qandq}{\quad\text{and}\quad}$
# $\newcommand{\qwhereq}{\quad\text{where}\quad}$
# $\newcommand{\qifq}{ \quad \text{if} \quad }$
# $\newcommand{\qarrq}{ \quad \Longrightarrow \quad }$
# $\newcommand{\ZZ}{\mathbb{Z}}$
# $\newcommand{\CC}{\mathbb{C}}$
# $\newcommand{\RR}{\mathbb{R}}$
# $\newcommand{\EE}{\mathbb{E}}$
# $\newcommand{\Zz}{\mathcal{Z}}$
# $\newcommand{\Ww}{\mathcal{W}}$
# $\newcommand{\Vv}{\mathcal{V}}$
# $\newcommand{\Nn}{\mathcal{N}}$
# $\newcommand{\NN}{\mathcal{N}}$
# $\newcommand{\Hh}{\mathcal{H}}$
# $\newcommand{\Bb}{\mathcal{B}}$
# $\newcommand{\Ee}{\mathcal{E}}$
# $\newcommand{\Cc}{\mathcal{C}}$
# $\newcommand{\Gg}{\mathcal{G}}$
# $\newcommand{\Ss}{\mathcal{S}}$
# $\newcommand{\Pp}{\mathcal{P}}$
# $\newcommand{\Ff}{\mathcal{F}}$
# $\newcommand{\Xx}{\mathcal{X}}$
# $\newcommand{\Mm}{\mathcal{M}}$
# $\newcommand{\Ii}{\mathcal{I}}$
# $\newcommand{\Dd}{\mathcal{D}}$
# $\newcommand{\Ll}{\mathcal{L}}$
# $\newcommand{\Tt}{\mathcal{T}}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\al}{\alpha}$
# $\newcommand{\la}{\lambda}$
# $\newcommand{\ga}{\gamma}$
# $\newcommand{\Ga}{\Gamma}$
# $\newcommand{\La}{\Lambda}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\Si}{\Sigma}$
# $\newcommand{\be}{\beta}$
# $\newcommand{\de}{\delta}$
# $\newcommand{\De}{\Delta}$
# $\newcommand{\phi}{\varphi}$
# $\newcommand{\th}{\theta}$
# $\newcommand{\om}{\omega}$
# $\newcommand{\Om}{\Omega}$

# %% [markdown]
# This numerical tour study image denoising using
# non-local means. This algorithm has been
# introduced for denoising purposes in [BuaCoMoA05](#biblio)

# %%
using PyPlot
using NtToolBox
# using Autoreload
# arequire("NtToolBox")
# Out:
# ┌ Info: Precompiling NtToolBox [077e15ba-1a11-4fec-9f4c-6ee2a1777f2a]
# └ @ Base loading.jl:1317
# ┌ Warning: Package NtToolBox does not have PyPlot in its dependencies:
# │ - If you have NtToolBox checked out for development and have
# │   added PyPlot as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with NtToolBox
# └ Loading PyPlot into NtToolBox from project dependency, future warnings for NtToolBox are suppressed.

# %% [markdown]
# Patches in Images
# -----------------
# This numerical tour is dedicated to the study of the structure of patches
# in images.
#
#
# Size $N = n \times n$ of the image.

# %%
n = 128;

# %% [markdown]
# We load a noisy image $f_0\in \RR^N$.

# %%
c = [100, 200]
f0 = load_image("NtToolBox/src/data/lena.png")
f0 = rescale(f0[c[1] - Base.div(n, 2) + 1 : c[1] + Base.div(n, 2), c[2] - Base.div(n, 2) + 1 : c[2] + Base.div(n, 2)]);

# %% [markdown]
# Display $f_0$.

# %%
figure(figsize = (5, 5))
imageplot(f0)
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %% [markdown]
# Noise level $\si$.

# %%
sigma = .04;

# %% [markdown]
# Generate a noisy image $f=f_0+\epsilon$ where $\epsilon \times
# \Nn(0,\si^2\text{Id}_N)$.

# %%
using Distributions
f = f0 .+ sigma.*rand(Normal(), n, n);

# %% [markdown]
# Display $f$.

# %%
figure(figsize = (5,5))
imageplot(clamP.(f))
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %% [markdown]
# We denote $w$ to be the half width of the patches,
# and $w_1=2w+1$ the full width.

# %%
w = 3
w1 = 2*w + 1;

# %% [markdown]
# We set up large $(n,n,w_1,w_1)$ matrices to index the the X and Y
# position of the pixel to extract.
#
# Location of pixels to extract.

# %%
include("NtToolBox/src/ndgrid.jl")

(Y, X, dX, dY) = ndgrid(1 : n, 1 : n, -w : w, -w : w)

X = X + dX
Y = Y + dY;

# %% [markdown]
# We handle boundary condition by reflexion

# %%
X[X .< 1] = 2 .- X[X .< 1] 
Y[Y .< 1] = 2 .- Y[Y .< 1]
X[X .> n] = 2*n .- X[X .> n]
Y[Y .> n] = 2*n .- Y[Y .> n];

# %% [markdown]
# Patch extractor operator.

# %%
I = X .+ (Y .- 1)*n

for k in 1 : Base.div(n, w)
    for l in 1 : Base.div(n, w)
        I[k, l, :, :] = transpose(I[k, l, :, :])
    end
end

function patch(f)
    return f'[I]
end;

# %% [markdown]
# Define the patch matrix $P$ of size $(n,n,w_1,w_1)$.
# Each $P(i,j,:,:)$ represent an $(w_1,w_1)$ patch extracted around pixel
# $(i,j)$ in the image.

# %%
P = patch(f);

# %% [markdown]
# Display some example of patches.

# %%
figure(figsize = (5,5))
for i in 1:16
    x = rand(1 : n)
    y = rand(1 : n)
    imageplot(P[x, y, :, :], "", [4, 4, i])
end
# Out:
# Figure(PyObject <Figure size 500x500 with 16 Axes>)

# %% [markdown]
# Dimensionality Reduction with PCA
# ---------------------------------
# Since NL-means type algorithms require the computation of many distances
# between patches, it is advantagous to reduce the dimensionality of the
# patch while keeping as much as possible of information.
#
#
# Target dimensionality $d$.

# %%
d = 25;

# %% [markdown]
# A linear dimensionality reduction is obtained by Principal Component
# Analysis (PCA) that projects the data on a small number of leading
# direction of the covariance matrix of the patches.
#
#
# Turn the patch matrix into an $(w_1*w_1,n*n)$ array, so that each $P(:,i)$
# is a $w_1*w_1$ vector representing a patch.

# %%
resh = P -> transpose((reshape(P, (n*n,w1*w1))));

# %% [markdown]
# Operator to remove the mean of the patches to each patch.

# %%
remove_mean = Q -> Q - repeat(mean(Q, dims=1), inner = (w1*w1, 1));

# %% [markdown]
# Compute the mean and the covariance of the points cloud representing the
# patches.

# %%
P1 = remove_mean(resh(P))
C = P1*transpose(P1);

# %% [markdown]
# Extract the eigenvectors, sorted by decreasing amplitude.

# %%
using LinearAlgebra
(D, V) = eigen(C)
D = D[end : -1 : 1]
V = V[:, end : -1 : 1];
# Out:
# WARNING: using LinearAlgebra.I in module Main conflicts with an existing identifier.

# %% [markdown]
# Display the decaying amplitude of the eigenvalues.

# %%
plot(D, linewidth = 2)
ylim(0, maximum(D))
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# sys:1: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# Display the leading eigenvectors - they look like Fourier modes.

# %%
figure(figsize = (5,5))
for i in 1 : 16
    imageplot(abs.(reshape(V[:, i], (w1,w1))'), "", [4, 4, i])
end
# Out:
# Figure(PyObject <Figure size 500x500 with 16 Axes>)

# %% [markdown]
# Patch dimensionality reduction operator.

# %%
iresh = Q -> reshape(Q', (n, n, d))
descriptor = f -> iresh(V[: , 1 : d]'*remove_mean(resh(P)));

# %% [markdown]
# Each $H(i,j,:)$ is a $d$-dimensional descriptor
# of a patch.

# %%
H = descriptor(f);

# %% [markdown]
# Non-local Filter
# ----------------
# NL-means applies, an adaptive averaging kernel
# is computed from patch distances to each pixel location.
#
#
# We denote $H_{i} \in \RR^d$ the descriptor at pixel $i$.
# We define the distance matrix
# $$ D_{i,j} = \frac{1}{w_1^2}\norm{H_i-H_j}^2. $$
#
#
#
# Operator to compute the distances $(D_{i,j})_j$ between the patch around $i=(i_1,i_2)$
# and all the other ones.

# %%
distance = i -> sum((H - repeat(reshape(H[i[1], i[2], :], (1, 1, 25)), inner = [n, n, 1])).^2, dims=3)./(w1*w1);

# %% [markdown]
# The non-local mean filter computes a denoised image $\tilde f$ as :
#
# $$ \tilde f_i = \sum_j K_{i,j} f_j $$
# where the weights $K$ are computed as :
# $$ K_{i,j} = \frac{ \tilde K_{i,j} }{ \sum_{j'} \tilde K_{i,j'} }
#       \qandq
#    \tilde K_{i,j} = e^{-\frac{D_{i,j}}{2\tau^2}} . $$
#
#
#
# The width $\tau$ of the Gaussian is very important and should be adapted to match
# the noise level.
#
#
#
# Compute and normalize the weight.

# %%
normalize = K -> K./sum(K)
kernel = (i, tau) -> normalize(exp.(-distance(i)./(2*tau^2)));

# %% [markdown]
# Compute a typical example of kernel for some pixel position $(x,y)$.

# %%
tau = .05
i = [84, 73]
D = distance(i)
K = kernel(i, tau);

# %% [markdown]
# Display the squared distance and the kernel.

# %%
figure(figsize = (10,10))
imageplot(D[:, :], "D", [1, 2, 1])
imageplot(K[:, :], "K", [1, 2, 2])
# Out:
# Figure(PyObject <Figure size 1000x1000 with 2 Axes>)
# PyObject Text(0.5, 1.0, 'K')

# %% [markdown]
# Localizing the Non-local Means
# ------------------------------
# We set a "locality constant" $q$ that set the maximum distance between
# patches to compare. This allows to speed up computation, and makes
# NL-means type methods semi-global (to avoid searching in all the image).

# %%
q = 14;

# %% [markdown]
# Using this locality constant, we compute the distance between patches
# only within a window.
# Once again, one should be careful about boundary conditions.

# %%
selection = i -> [clamP.(i[1] - q : i[1] + q, 1, n)'; clamP.(i[2] - q : i[2] + q, 1, n)'];

# %% [markdown]
# Compute distance and kernel only within the window.

# %%
function distance_0(i,sel)
    H1 = (H[sel[1, :], :, :])
    H2 = (H1[:, sel[2, :], :])
    return sum((H2 - repeat(reshape(H[i[1], i[2], :], (1, 1, length(H[i[1], i[2], :]))), inner = [length(sel[1, :]), length(sel[1, :]), 1])).^2, dims=3)/w1*w1
end

distance = i -> distance_0(i, selection(i))
kernel = (i, tau) -> normalize(exp.(-distance(i)./(2*tau^2)));

# %% [markdown]
# Compute a typical example of kernel for some pixel position $(x,y)$.

# %% [markdown]
# Display the squared distance and the kernel.

# %%
sel = selection(i)
D = distance(i)
#K = kernel(i, tau);

# %%
figure(figsize = (10,10))

imageplot(D[:, :], "D", [1, 2, 1])
imageplot(K[:, :], "K", [1, 2, 2])
# Out:
# Figure(PyObject <Figure size 1000x1000 with 2 Axes>)
# PyObject Text(0.5, 1.0, 'K')

# %% [markdown]
# The NL-filtered value at pixel $(x,y)$ is obtained by averaging the values
# of $f$ with the weight $K$.

# %%
function NLval_0(K,sel)
    f_temp = f[sel[1, :], :]
    return sum(K.*f_temp[:, sel[2, :]])
end

NLval = (i, ta) -> NLval_0(kernel(i, tau), selection(i));

# %% [markdown]
# We apply the filter to each pixel location
# to perform the NL-means algorithm.

# %%
(Y, X) = meshgrid(0 : n - 1, 0 : n - 1)

function arrayfun(f, X, Y)
    n = size(X)[1]
    p = size(Y)[1]
    R = zeros(n, p)
    for k in 1:n
        for l in 1:p
            R[k,l] = f(k,l)
        end
    end
    return R
end

NLmeans = tau -> arrayfun((i1, i2) -> NLval([i1,i2], tau), X, Y);

# %% [markdown]
# Display the result for some value of $\tau$.

# %%
tau = .03

figure(figsize = (5,5))
imageplot(NLmeans(tau))
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %%
tau = .03;

# %% [markdown]
# __Exercise 1__
#
# Compute the denoising result for several values of $\tau$ in order to
# determine the optimal denoising that minimizes $\norm{\tilde f - f_0}$.

# %%
include("NtSolutions/denoisingadv_6_nl_means/exo1.jl")
# Out:
# Figure(PyObject <Figure size 1000x1000 with 4 Axes>)
# ┌ Warning: Assignment to `tau` in soft scope is ambiguous because a global variable by the same name exists: `tau` will be treated as a new local. Disambiguate by using `local tau` to suppress this warning or `global tau` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo1.jl:9

# %%
## Insert your code here.

# %% [markdown]
# Display the best result.

# %%
figure(figsize = (5,5))
imageplot(clamP.(fNL))
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)

# %% [markdown]
# __Exercise 2__
#
# Explore the influence of the $q$ and $w$ parameters.

# %%
include("NtSolutions/denoisingadv_6_nl_means/exo2.jl")
# Out:
# Figure(PyObject <Figure size 1000x1000 with 4 Axes>)
# ┌ Warning: Assignment to `w` in soft scope is ambiguous because a global variable by the same name exists: `w` will be treated as a new local. Disambiguate by using `local w` to suppress this warning or `global w` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:11
# ┌ Warning: Assignment to `q` in soft scope is ambiguous because a global variable by the same name exists: `q` will be treated as a new local. Disambiguate by using `local q` to suppress this warning or `global q` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:12
# ┌ Warning: Assignment to `w1` in soft scope is ambiguous because a global variable by the same name exists: `w1` will be treated as a new local. Disambiguate by using `local w1` to suppress this warning or `global w1` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:16
# ┌ Warning: Assignment to `Y` in soft scope is ambiguous because a global variable by the same name exists: `Y` will be treated as a new local. Disambiguate by using `local Y` to suppress this warning or `global Y` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:18
# ┌ Warning: Assignment to `X` in soft scope is ambiguous because a global variable by the same name exists: `X` will be treated as a new local. Disambiguate by using `local X` to suppress this warning or `global X` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:18
# ┌ Warning: Assignment to `dX` in soft scope is ambiguous because a global variable by the same name exists: `dX` will be treated as a new local. Disambiguate by using `local dX` to suppress this warning or `global dX` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:18
# ┌ Warning: Assignment to `dY` in soft scope is ambiguous because a global variable by the same name exists: `dY` will be treated as a new local. Disambiguate by using `local dY` to suppress this warning or `global dY` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:18
# ┌ Warning: Assignment to `I` in soft scope is ambiguous because a global variable by the same name exists: `I` will be treated as a new local. Disambiguate by using `local I` to suppress this warning or `global I` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:27
# ┌ Warning: Assignment to `P` in soft scope is ambiguous because a global variable by the same name exists: `P` will be treated as a new local. Disambiguate by using `local P` to suppress this warning or `global P` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:39
# ┌ Warning: Assignment to `resh` in soft scope is ambiguous because a global variable by the same name exists: `resh` will be treated as a new local. Disambiguate by using `local resh` to suppress this warning or `global resh` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:42
# ┌ Warning: Assignment to `remove_mean` in soft scope is ambiguous because a global variable by the same name exists: `remove_mean` will be treated as a new local. Disambiguate by using `local remove_mean` to suppress this warning or `global remove_mean` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:43
# ┌ Warning: Assignment to `P1` in soft scope is ambiguous because a global variable by the same name exists: `P1` will be treated as a new local. Disambiguate by using `local P1` to suppress this warning or `global P1` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:45
# ┌ Warning: Assignment to `C` in soft scope is ambiguous because a global variable by the same name exists: `C` will be treated as a new local. Disambiguate by using `local C` to suppress this warning or `global C` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:46
# ┌ Warning: Assignment to `D` in soft scope is ambiguous because a global variable by the same name exists: `D` will be treated as a new local. Disambiguate by using `local D` to suppress this warning or `global D` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:47
# ┌ Warning: Assignment to `V` in soft scope is ambiguous because a global variable by the same name exists: `V` will be treated as a new local. Disambiguate by using `local V` to suppress this warning or `global V` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:47
# ┌ Warning: Assignment to `iresh` in soft scope is ambiguous because a global variable by the same name exists: `iresh` will be treated as a new local. Disambiguate by using `local iresh` to suppress this warning or `global iresh` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:51
# ┌ Warning: Assignment to `descriptor` in soft scope is ambiguous because a global variable by the same name exists: `descriptor` will be treated as a new local. Disambiguate by using `local descriptor` to suppress this warning or `global descriptor` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:52
# ┌ Warning: Assignment to `H` in soft scope is ambiguous because a global variable by the same name exists: `H` will be treated as a new local. Disambiguate by using `local H` to suppress this warning or `global H` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:54
# ┌ Warning: Assignment to `i` in soft scope is ambiguous because a global variable by the same name exists: `i` will be treated as a new local. Disambiguate by using `local i` to suppress this warning or `global i` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:57
# ┌ Warning: Assignment to `distance` in soft scope is ambiguous because a global variable by the same name exists: `distance` will be treated as a new local. Disambiguate by using `local distance` to suppress this warning or `global distance` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:65
# ┌ Warning: Assignment to `kernel` in soft scope is ambiguous because a global variable by the same name exists: `kernel` will be treated as a new local. Disambiguate by using `local kernel` to suppress this warning or `global kernel` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:66
# ┌ Warning: Assignment to `selection` in soft scope is ambiguous because a global variable by the same name exists: `selection` will be treated as a new local. Disambiguate by using `local selection` to suppress this warning or `global selection` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:67
# ┌ Warning: Assignment to `NLval` in soft scope is ambiguous because a global variable by the same name exists: `NLval` will be treated as a new local. Disambiguate by using `local NLval` to suppress this warning or `global NLval` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:75
# ┌ Warning: Assignment to `NLmeans` in soft scope is ambiguous because a global variable by the same name exists: `NLmeans` will be treated as a new local. Disambiguate by using `local NLmeans` to suppress this warning or `global NLmeans` to assign to the existing global variable.
# └ @ nothing c:\Users\Abhi\git\numerical-tours-AJ\julia\NtSolutions\denoisingadv_6_nl_means\exo2.jl:76

# %%
## Insert your code here.

# %% [markdown]
# Bibliography
# ------------
# <html><a name="biblio"></a></html>
#
#
# * [BuaCoMoA05] Buades, B. Coll, J.f Morel, [A review of image denoising algorithms, with a new one][1], SIAM Multiscale Modeling and Simulation, Vol 4 (2), pp: 490-530, 2005.
#
# [1]:http://dx.doi.org/10.1137/040616024
